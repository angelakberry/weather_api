# %%
import requests
import pandas as pd
from datetime import datetime

# %%
api_key = #"my_api_key"
baseurl = "http://api.weatherapi.com/v1"
# f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}"
city = "Louisville"

# %%
response = requests.get(f"http://api.weatherapi.com/v1/current.json?key={api_key}&q={city}")

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()
data['current']
# Out:
# {'last_updated_epoch': 1758159000,
#  'last_updated': '2025-09-17 21:30',
#  'temp_c': 26.7,
#  'temp_f': 80.1,
#  'is_day': 0,
#  'condition': {'text': 'Clear',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#   'code': 1000},
#  'wind_mph': 3.6,
#  'wind_kph': 5.8,
#  'wind_degree': 353,
#  'wind_dir': 'N',
#  'pressure_mb': 1016.0,
#  'pressure_in': 30.01,
#  'precip_mm': 0.0,
#  'precip_in': 0.0,
#  'humidity': 39,
#  'cloud': 25,
#  'feelslike_c': 27.2,
#  'feelslike_f': 81.0,
#  'windchill_c': 27.2,
#  'windchill_f': 80.9,
#  'heatindex_c': 27.8,
#  'heatindex_f': 82.0,
#  'dewpoint_c': 15.3,
#  'dewpoint_f': 59.6,
#  'vis_km': 16.0,
#  'vis_miles': 9.0,
#  'uv': 0.0,
#  'gust_mph': 7.5,
#  'gust_kph': 12.1,
#  'short_rad': 0,
#  'diff_rad': 0,
#  'dni': 0,
#  'gti': 0}

# %%
forecast_url = f"{baseurl}/forecast.json?key={api_key}&q={city}&days=3"
forecast_response = requests.get(forecast_url)
forecast_response.status_code
# Out:
# 200

# %%
forecast_data = forecast_response.json()
forecast = forecast_data['forecast']['forecastday']
forecast
# Out:
# [{'date': '2025-09-17',
#   'date_epoch': 1758067200,
#   'day': {'maxtemp_c': 34.0,
#    'maxtemp_f': 93.2,
#    'mintemp_c': 19.5,
#    'mintemp_f': 67.1,
#    'avgtemp_c': 26.4,
#    'avgtemp_f': 79.5,
#    'maxwind_mph': 4.9,
#    'maxwind_kph': 7.9,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 58,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'uv': 1.6},
#   'astro': {'sunrise': '07:27 AM',
#    'sunset': '07:48 PM',
#    'moonrise': '02:53 AM',
#    'moonset': '05:55 PM',
#    'moon_phase': 'Waning Crescent',
#    'moon_illumination': 23,
#    'is_moon_up': 0,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1758081600,
#     'time': '2025-09-17 00:00',
#     'temp_c': 23.5,
#     'temp_f': 74.3,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 137,
#     'wind_dir': 'SE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 67,
#     'cloud': 36,
#     'feelslike_c': 25.3,
#     'feelslike_f': 77.6,
#     'windchill_c': 23.5,
#     'windchill_f': 74.3,
#     'heatindex_c': 25.3,
#     'heatindex_f': 77.6,
#     'dewpoint_c': 16.8,
#     'dewpoint_f': 62.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.4,
#     'gust_kph': 11.9,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758085200,
#     'time': '2025-09-17 01:00',
#     'temp_c': 22.9,
#     'temp_f': 73.1,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 172,
#     'wind_dir': 'S',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 68,
#     'cloud': 31,
#     'feelslike_c': 25.0,
#     'feelslike_f': 76.9,
#     'windchill_c': 22.9,
#     'windchill_f': 73.1,
#     'heatindex_c': 25.0,
#     'heatindex_f': 76.9,
#     'dewpoint_c': 16.7,
#     'dewpoint_f': 62.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758088800,
#     'time': '2025-09-17 02:00',
#     'temp_c': 22.3,
#     'temp_f': 72.1,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 141,
#     'wind_dir': 'SE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 17,
#     'feelslike_c': 24.7,
#     'feelslike_f': 76.5,
#     'windchill_c': 22.3,
#     'windchill_f': 72.1,
#     'heatindex_c': 24.7,
#     'heatindex_f': 76.5,
#     'dewpoint_c': 17.0,
#     'dewpoint_f': 62.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758092400,
#     'time': '2025-09-17 03:00',
#     'temp_c': 21.6,
#     'temp_f': 71.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 97,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 77,
#     'cloud': 8,
#     'feelslike_c': 21.6,
#     'feelslike_f': 71.0,
#     'windchill_c': 21.6,
#     'windchill_f': 71.0,
#     'heatindex_c': 22.9,
#     'heatindex_f': 73.1,
#     'dewpoint_c': 17.5,
#     'dewpoint_f': 63.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.9,
#     'gust_kph': 11.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758096000,
#     'time': '2025-09-17 04:00',
#     'temp_c': 21.3,
#     'temp_f': 70.3,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 96,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 82,
#     'cloud': 17,
#     'feelslike_c': 21.3,
#     'feelslike_f': 70.3,
#     'windchill_c': 21.3,
#     'windchill_f': 70.3,
#     'heatindex_c': 21.9,
#     'heatindex_f': 71.4,
#     'dewpoint_c': 17.7,
#     'dewpoint_f': 63.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.4,
#     'gust_kph': 10.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758099600,
#     'time': '2025-09-17 05:00',
#     'temp_c': 20.9,
#     'temp_f': 69.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 95,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 73,
#     'cloud': 58,
#     'feelslike_c': 20.9,
#     'feelslike_f': 69.6,
#     'windchill_c': 20.9,
#     'windchill_f': 69.6,
#     'heatindex_c': 21.2,
#     'heatindex_f': 70.1,
#     'dewpoint_c': 15.9,
#     'dewpoint_f': 60.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758103200,
#     'time': '2025-09-17 06:00',
#     'temp_c': 20.4,
#     'temp_f': 68.7,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 94,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 77,
#     'cloud': 52,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.7,
#     'windchill_c': 20.4,
#     'windchill_f': 68.7,
#     'heatindex_c': 20.5,
#     'heatindex_f': 69.0,
#     'dewpoint_c': 16.3,
#     'dewpoint_f': 61.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.2,
#     'gust_kph': 8.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758106800,
#     'time': '2025-09-17 07:00',
#     'temp_c': 19.9,
#     'temp_f': 67.9,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 90,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 81,
#     'cloud': 17,
#     'feelslike_c': 19.9,
#     'feelslike_f': 67.9,
#     'windchill_c': 19.9,
#     'windchill_f': 67.9,
#     'heatindex_c': 20.0,
#     'heatindex_f': 68.0,
#     'dewpoint_c': 16.5,
#     'dewpoint_f': 61.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758110400,
#     'time': '2025-09-17 08:00',
#     'temp_c': 20.4,
#     'temp_f': 68.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 83,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 84,
#     'cloud': 8,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.8,
#     'windchill_c': 20.4,
#     'windchill_f': 68.8,
#     'heatindex_c': 20.5,
#     'heatindex_f': 68.8,
#     'dewpoint_c': 16.7,
#     'dewpoint_f': 62.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.8,
#     'uv': 0.0,
#     'short_rad': 1.68,
#     'diff_rad': 0.81,
#     'dni': 1.18,
#     'gti': 1.05},
#    {'time_epoch': 1758114000,
#     'time': '2025-09-17 09:00',
#     'temp_c': 21.9,
#     'temp_f': 71.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 97,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 78,
#     'cloud': 1,
#     'feelslike_c': 21.9,
#     'feelslike_f': 71.4,
#     'windchill_c': 21.9,
#     'windchill_f': 71.4,
#     'heatindex_c': 22.9,
#     'heatindex_f': 73.1,
#     'dewpoint_c': 16.9,
#     'dewpoint_f': 62.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.6,
#     'uv': 0.6,
#     'short_rad': 140.34,
#     'diff_rad': 44.97,
#     'dni': 119.78,
#     'gti': 74.83},
#    {'time_epoch': 1758117600,
#     'time': '2025-09-17 10:00',
#     'temp_c': 25.7,
#     'temp_f': 78.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 98,
#     'wind_dir': 'E',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 70,
#     'cloud': 0,
#     'feelslike_c': 27.4,
#     'feelslike_f': 81.4,
#     'windchill_c': 25.7,
#     'windchill_f': 78.3,
#     'heatindex_c': 27.4,
#     'heatindex_f': 81.4,
#     'dewpoint_c': 17.6,
#     'dewpoint_f': 63.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.6,
#     'gust_kph': 5.8,
#     'uv': 1.7,
#     'short_rad': 238.44,
#     'diff_rad': 59.28,
#     'dni': 223.19,
#     'gti': 117.44},
#    {'time_epoch': 1758121200,
#     'time': '2025-09-17 11:00',
#     'temp_c': 28.7,
#     'temp_f': 83.7,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 97,
#     'wind_dir': 'E',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 59,
#     'cloud': 0,
#     'feelslike_c': 30.6,
#     'feelslike_f': 87.1,
#     'windchill_c': 28.7,
#     'windchill_f': 83.7,
#     'heatindex_c': 30.6,
#     'heatindex_f': 87.1,
#     'dewpoint_c': 20.7,
#     'dewpoint_f': 69.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.1,
#     'gust_kph': 6.6,
#     'uv': 3.4,
#     'short_rad': 332.88,
#     'diff_rad': 69.47,
#     'dni': 348.44,
#     'gti': 156.99},
#    {'time_epoch': 1758124800,
#     'time': '2025-09-17 12:00',
#     'temp_c': 30.9,
#     'temp_f': 87.5,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 83,
#     'wind_dir': 'E',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 47,
#     'cloud': 0,
#     'feelslike_c': 32.4,
#     'feelslike_f': 90.2,
#     'windchill_c': 30.9,
#     'windchill_f': 87.5,
#     'heatindex_c': 32.4,
#     'heatindex_f': 90.2,
#     'dewpoint_c': 19.0,
#     'dewpoint_f': 66.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.4,
#     'gust_kph': 7.1,
#     'uv': 5.2,
#     'short_rad': 417.76,
#     'diff_rad': 76.59,
#     'dni': 517.6,
#     'gti': 192.8},
#    {'time_epoch': 1758128400,
#     'time': '2025-09-17 13:00',
#     'temp_c': 32.2,
#     'temp_f': 90.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 76,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 38,
#     'cloud': 0,
#     'feelslike_c': 33.4,
#     'feelslike_f': 92.1,
#     'windchill_c': 32.2,
#     'windchill_f': 90.0,
#     'heatindex_c': 33.4,
#     'heatindex_f': 92.1,
#     'dewpoint_c': 17.0,
#     'dewpoint_f': 62.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.9,
#     'gust_kph': 6.2,
#     'uv': 6.4,
#     'short_rad': 488.42,
#     'diff_rad': 81.84,
#     'dni': 783.66,
#     'gti': 225.51},
#    {'time_epoch': 1758132000,
#     'time': '2025-09-17 14:00',
#     'temp_c': 33.1,
#     'temp_f': 91.5,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.5,
#     'wind_kph': 4.0,
#     'wind_degree': 59,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 35,
#     'cloud': 0,
#     'feelslike_c': 34.1,
#     'feelslike_f': 93.4,
#     'windchill_c': 33.1,
#     'windchill_f': 91.5,
#     'heatindex_c': 34.1,
#     'heatindex_f': 93.4,
#     'dewpoint_c': 16.2,
#     'dewpoint_f': 61.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.8,
#     'gust_kph': 4.6,
#     'uv': 6.7,
#     'short_rad': 541.94,
#     'diff_rad': 85.77,
#     'dni': 1323.89,
#     'gti': 259.2},
#    {'time_epoch': 1758135600,
#     'time': '2025-09-17 15:00',
#     'temp_c': 33.5,
#     'temp_f': 92.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.0,
#     'wind_kph': 3.2,
#     'wind_degree': 31,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 35,
#     'cloud': 0,
#     'feelslike_c': 34.5,
#     'feelslike_f': 94.2,
#     'windchill_c': 33.5,
#     'windchill_f': 92.4,
#     'heatindex_c': 34.5,
#     'heatindex_f': 94.2,
#     'dewpoint_c': 16.3,
#     'dewpoint_f': 61.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.3,
#     'gust_kph': 3.7,
#     'uv': 5.8,
#     'short_rad': 785.66,
#     'diff_rad': 102.94,
#     'dni': 4605.08,
#     'gti': 433.97},
#    {'time_epoch': 1758139200,
#     'time': '2025-09-17 16:00',
#     'temp_c': 33.4,
#     'temp_f': 92.1,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 357,
#     'wind_dir': 'N',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.0,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 35,
#     'cloud': 0,
#     'feelslike_c': 34.2,
#     'feelslike_f': 93.6,
#     'windchill_c': 33.4,
#     'windchill_f': 92.1,
#     'heatindex_c': 34.2,
#     'heatindex_f': 93.6,
#     'dewpoint_c': 16.4,
#     'dewpoint_f': 61.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.6,
#     'gust_kph': 4.1,
#     'uv': 4.2,
#     'short_rad': 743.54,
#     'diff_rad': 100.1,
#     'dni': 0.0,
#     'gti': 105.32},
#    {'time_epoch': 1758142800,
#     'time': '2025-09-17 17:00',
#     'temp_c': 32.6,
#     'temp_f': 90.6,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 336,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 29.99,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 36,
#     'cloud': 0,
#     'feelslike_c': 33.2,
#     'feelslike_f': 91.8,
#     'windchill_c': 32.6,
#     'windchill_f': 90.6,
#     'heatindex_c': 33.2,
#     'heatindex_f': 91.8,
#     'dewpoint_c': 16.1,
#     'dewpoint_f': 61.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.6,
#     'gust_kph': 5.8,
#     'uv': 2.4,
#     'short_rad': 683.54,
#     'diff_rad': 96.14,
#     'dni': 0.0,
#     'gti': 100.5},
#    {'time_epoch': 1758146400,
#     'time': '2025-09-17 18:00',
#     'temp_c': 31.3,
#     'temp_f': 88.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.0,
#     'wind_kph': 6.5,
#     'wind_degree': 319,
#     'wind_dir': 'NW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 29.99,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 37,
#     'cloud': 0,
#     'feelslike_c': 31.7,
#     'feelslike_f': 89.0,
#     'windchill_c': 31.3,
#     'windchill_f': 88.3,
#     'heatindex_c': 31.7,
#     'heatindex_f': 89.0,
#     'dewpoint_c': 15.5,
#     'dewpoint_f': 59.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.0,
#     'gust_kph': 8.1,
#     'uv': 1.0,
#     'short_rad': 608.94,
#     'diff_rad': 90.7,
#     'dni': 0.0,
#     'gti': 94.03},
#    {'time_epoch': 1758150000,
#     'time': '2025-09-17 19:00',
#     'temp_c': 29.6,
#     'temp_f': 85.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.9,
#     'wind_kph': 7.9,
#     'wind_degree': 303,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.0,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 40,
#     'cloud': 0,
#     'feelslike_c': 29.9,
#     'feelslike_f': 85.8,
#     'windchill_c': 29.6,
#     'windchill_f': 85.3,
#     'heatindex_c': 29.9,
#     'heatindex_f': 85.8,
#     'dewpoint_c': 15.1,
#     'dewpoint_f': 59.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.6,
#     'gust_kph': 13.9,
#     'uv': 0.2,
#     'short_rad': 524.72,
#     'diff_rad': 82.85,
#     'dni': 0.0,
#     'gti': 85.22},
#    {'time_epoch': 1758153600,
#     'time': '2025-09-17 20:00',
#     'temp_c': 28.2,
#     'temp_f': 82.8,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 4.5,
#     'wind_kph': 7.2,
#     'wind_degree': 308,
#     'wind_dir': 'NW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 29.99,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 45,
#     'cloud': 0,
#     'feelslike_c': 28.7,
#     'feelslike_f': 83.6,
#     'windchill_c': 28.2,
#     'windchill_f': 82.8,
#     'heatindex_c': 28.7,
#     'heatindex_f': 83.6,
#     'dewpoint_c': 14.8,
#     'dewpoint_f': 58.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 9.4,
#     'gust_kph': 15.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758157200,
#     'time': '2025-09-17 21:00',
#     'temp_c': 26.7,
#     'temp_f': 80.1,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 353,
#     'wind_dir': 'N',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 25,
#     'feelslike_c': 27.8,
#     'feelslike_f': 82.0,
#     'windchill_c': 27.2,
#     'windchill_f': 80.9,
#     'heatindex_c': 27.8,
#     'heatindex_f': 82.0,
#     'dewpoint_c': 15.3,
#     'dewpoint_f': 59.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 16.0,
#     'vis_miles': 9.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758160800,
#     'time': '2025-09-17 22:00',
#     'temp_c': 26.2,
#     'temp_f': 79.1,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 38,
#     'wind_dir': 'NE',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 53,
#     'cloud': 1,
#     'feelslike_c': 27.0,
#     'feelslike_f': 80.6,
#     'windchill_c': 26.2,
#     'windchill_f': 79.1,
#     'heatindex_c': 27.0,
#     'heatindex_f': 80.6,
#     'dewpoint_c': 15.7,
#     'dewpoint_f': 60.3,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.5,
#     'gust_kph': 12.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758164400,
#     'time': '2025-09-17 23:00',
#     'temp_c': 25.1,
#     'temp_f': 77.2,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 62,
#     'wind_dir': 'ENE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 55,
#     'cloud': 2,
#     'feelslike_c': 26.2,
#     'feelslike_f': 79.1,
#     'windchill_c': 25.1,
#     'windchill_f': 77.2,
#     'heatindex_c': 26.2,
#     'heatindex_f': 79.1,
#     'dewpoint_c': 15.7,
#     'dewpoint_f': 60.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]},
#  {'date': '2025-09-18',
#   'date_epoch': 1758153600,
#   'day': {'maxtemp_c': 33.2,
#    'maxtemp_f': 91.8,
#    'mintemp_c': 19.3,
#    'mintemp_f': 66.7,
#    'avgtemp_c': 25.8,
#    'avgtemp_f': 78.5,
#    'maxwind_mph': 4.3,
#    'maxwind_kph': 6.8,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 54,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'uv': 1.6},
#   'astro': {'sunrise': '07:28 AM',
#    'sunset': '07:46 PM',
#    'moonrise': '04:02 AM',
#    'moonset': '06:25 PM',
#    'moon_phase': 'Waning Crescent',
#    'moon_illumination': 15,
#    'is_moon_up': 0,
#    'is_sun_up': 0},
#   'hour': [{'time_epoch': 1758168000,
#     'time': '2025-09-18 00:00',
#     'temp_c': 24.1,
#     'temp_f': 75.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 112,
#     'wind_dir': 'ESE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 57,
#     'cloud': 2,
#     'feelslike_c': 25.6,
#     'feelslike_f': 78.0,
#     'windchill_c': 24.1,
#     'windchill_f': 75.4,
#     'heatindex_c': 25.6,
#     'heatindex_f': 78.0,
#     'dewpoint_c': 15.0,
#     'dewpoint_f': 59.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.8,
#     'gust_kph': 4.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758171600,
#     'time': '2025-09-18 01:00',
#     'temp_c': 23.2,
#     'temp_f': 73.8,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 1.8,
#     'wind_kph': 2.9,
#     'wind_degree': 145,
#     'wind_dir': 'SE',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 59,
#     'cloud': 0,
#     'feelslike_c': 25.1,
#     'feelslike_f': 77.2,
#     'windchill_c': 23.2,
#     'windchill_f': 73.8,
#     'heatindex_c': 25.1,
#     'heatindex_f': 77.2,
#     'dewpoint_c': 14.8,
#     'dewpoint_f': 58.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.8,
#     'gust_kph': 6.0,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758175200,
#     'time': '2025-09-18 02:00',
#     'temp_c': 22.4,
#     'temp_f': 72.4,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.7,
#     'wind_kph': 4.3,
#     'wind_degree': 157,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 62,
#     'cloud': 0,
#     'feelslike_c': 24.8,
#     'feelslike_f': 76.7,
#     'windchill_c': 22.4,
#     'windchill_f': 72.4,
#     'heatindex_c': 24.8,
#     'heatindex_f': 76.7,
#     'dewpoint_c': 14.7,
#     'dewpoint_f': 58.4,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.6,
#     'gust_kph': 9.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758178800,
#     'time': '2025-09-18 03:00',
#     'temp_c': 21.7,
#     'temp_f': 71.1,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 155,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 65,
#     'cloud': 0,
#     'feelslike_c': 21.7,
#     'feelslike_f': 71.1,
#     'windchill_c': 21.7,
#     'windchill_f': 71.1,
#     'heatindex_c': 22.9,
#     'heatindex_f': 73.2,
#     'dewpoint_c': 14.8,
#     'dewpoint_f': 58.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758182400,
#     'time': '2025-09-18 04:00',
#     'temp_c': 21.1,
#     'temp_f': 70.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 174,
#     'wind_dir': 'S',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 70,
#     'cloud': 0,
#     'feelslike_c': 21.1,
#     'feelslike_f': 70.0,
#     'windchill_c': 21.1,
#     'windchill_f': 70.0,
#     'heatindex_c': 21.7,
#     'heatindex_f': 71.1,
#     'dewpoint_c': 15.3,
#     'dewpoint_f': 59.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.1,
#     'gust_kph': 9.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758186000,
#     'time': '2025-09-18 05:00',
#     'temp_c': 20.6,
#     'temp_f': 69.0,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 208,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 72,
#     'cloud': 7,
#     'feelslike_c': 20.6,
#     'feelslike_f': 69.0,
#     'windchill_c': 20.6,
#     'windchill_f': 69.0,
#     'heatindex_c': 20.9,
#     'heatindex_f': 69.5,
#     'dewpoint_c': 15.4,
#     'dewpoint_f': 59.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.6,
#     'gust_kph': 10.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758189600,
#     'time': '2025-09-18 06:00',
#     'temp_c': 20.1,
#     'temp_f': 68.2,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.7,
#     'wind_kph': 4.3,
#     'wind_degree': 211,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 74,
#     'cloud': 19,
#     'feelslike_c': 20.1,
#     'feelslike_f': 68.2,
#     'windchill_c': 20.1,
#     'windchill_f': 68.2,
#     'heatindex_c': 20.3,
#     'heatindex_f': 68.5,
#     'dewpoint_c': 15.3,
#     'dewpoint_f': 59.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 5.6,
#     'gust_kph': 9.1,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758193200,
#     'time': '2025-09-18 07:00',
#     'temp_c': 19.7,
#     'temp_f': 67.5,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.0,
#     'wind_kph': 3.2,
#     'wind_degree': 200,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 76,
#     'cloud': 0,
#     'feelslike_c': 19.7,
#     'feelslike_f': 67.5,
#     'windchill_c': 19.7,
#     'windchill_f': 67.5,
#     'heatindex_c': 19.8,
#     'heatindex_f': 67.6,
#     'dewpoint_c': 15.4,
#     'dewpoint_f': 59.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.2,
#     'gust_kph': 6.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758196800,
#     'time': '2025-09-18 08:00',
#     'temp_c': 20.4,
#     'temp_f': 68.7,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 188,
#     'wind_dir': 'S',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 76,
#     'cloud': 0,
#     'feelslike_c': 20.4,
#     'feelslike_f': 68.7,
#     'windchill_c': 20.4,
#     'windchill_f': 68.7,
#     'heatindex_c': 22.1,
#     'heatindex_f': 71.8,
#     'dewpoint_c': 15.1,
#     'dewpoint_f': 59.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.8,
#     'gust_kph': 4.5,
#     'uv': 0.0,
#     'short_rad': 1.6,
#     'diff_rad': 0.76,
#     'dni': 1.15,
#     'gti': 0.99},
#    {'time_epoch': 1758200400,
#     'time': '2025-09-18 09:00',
#     'temp_c': 22.4,
#     'temp_f': 72.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.6,
#     'wind_kph': 2.5,
#     'wind_degree': 208,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 68,
#     'cloud': 0,
#     'feelslike_c': 23.9,
#     'feelslike_f': 75.0,
#     'windchill_c': 22.4,
#     'windchill_f': 72.3,
#     'heatindex_c': 23.9,
#     'heatindex_f': 75.0,
#     'dewpoint_c': 14.9,
#     'dewpoint_f': 58.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.4,
#     'gust_kph': 3.9,
#     'uv': 0.6,
#     'short_rad': 138.84,
#     'diff_rad': 43.4,
#     'dni': 120.44,
#     'gti': 72.8},
#    {'time_epoch': 1758204000,
#     'time': '2025-09-18 10:00',
#     'temp_c': 26.1,
#     'temp_f': 79.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.6,
#     'wind_kph': 2.5,
#     'wind_degree': 196,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 57,
#     'cloud': 0,
#     'feelslike_c': 27.4,
#     'feelslike_f': 81.3,
#     'windchill_c': 26.1,
#     'windchill_f': 79.0,
#     'heatindex_c': 27.4,
#     'heatindex_f': 81.3,
#     'dewpoint_c': 15.4,
#     'dewpoint_f': 59.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 1.8,
#     'gust_kph': 2.9,
#     'uv': 1.7,
#     'short_rad': 236.94,
#     'diff_rad': 57.16,
#     'dni': 225.12,
#     'gti': 114.56},
#    {'time_epoch': 1758207600,
#     'time': '2025-09-18 11:00',
#     'temp_c': 28.8,
#     'temp_f': 83.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.0,
#     'wind_kph': 3.2,
#     'wind_degree': 211,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 48,
#     'cloud': 0,
#     'feelslike_c': 29.9,
#     'feelslike_f': 85.7,
#     'windchill_c': 28.8,
#     'windchill_f': 83.8,
#     'heatindex_c': 29.9,
#     'heatindex_f': 85.7,
#     'dewpoint_c': 17.7,
#     'dewpoint_f': 63.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.3,
#     'gust_kph': 3.7,
#     'uv': 3.4,
#     'short_rad': 331.28,
#     'diff_rad': 67.01,
#     'dni': 351.66,
#     'gti': 153.23},
#    {'time_epoch': 1758211200,
#     'time': '2025-09-18 12:00',
#     'temp_c': 30.7,
#     'temp_f': 87.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 242,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 41,
#     'cloud': 0,
#     'feelslike_c': 31.7,
#     'feelslike_f': 89.1,
#     'windchill_c': 30.7,
#     'windchill_f': 87.2,
#     'heatindex_c': 31.7,
#     'heatindex_f': 89.1,
#     'dewpoint_c': 16.6,
#     'dewpoint_f': 61.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.4,
#     'gust_kph': 5.4,
#     'uv': 5.2,
#     'short_rad': 415.71,
#     'diff_rad': 74.28,
#     'dni': 521.77,
#     'gti': 188.1},
#    {'time_epoch': 1758214800,
#     'time': '2025-09-18 13:00',
#     'temp_c': 31.9,
#     'temp_f': 89.5,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 266,
#     'wind_dir': 'W',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 0,
#     'feelslike_c': 33.1,
#     'feelslike_f': 91.6,
#     'windchill_c': 31.9,
#     'windchill_f': 89.5,
#     'heatindex_c': 33.1,
#     'heatindex_f': 91.6,
#     'dewpoint_c': 17.0,
#     'dewpoint_f': 62.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.9,
#     'gust_kph': 6.2,
#     'uv': 6.5,
#     'short_rad': 485.95,
#     'diff_rad': 79.68,
#     'dni': 790.74,
#     'gti': 219.42},
#    {'time_epoch': 1758218400,
#     'time': '2025-09-18 14:00',
#     'temp_c': 31.9,
#     'temp_f': 89.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 290,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 0,
#     'feelslike_c': 32.9,
#     'feelslike_f': 91.2,
#     'windchill_c': 31.9,
#     'windchill_f': 89.4,
#     'heatindex_c': 32.9,
#     'heatindex_f': 91.2,
#     'dewpoint_c': 17.3,
#     'dewpoint_f': 63.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.4,
#     'gust_kph': 7.1,
#     'uv': 6.7,
#     'short_rad': 539.2,
#     'diff_rad': 83.58,
#     'dni': 1342.7,
#     'gti': 250.37},
#    {'time_epoch': 1758222000,
#     'time': '2025-09-18 15:00',
#     'temp_c': 31.6,
#     'temp_f': 88.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 309,
#     'wind_dir': 'NW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.02,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 39,
#     'cloud': 33,
#     'feelslike_c': 32.3,
#     'feelslike_f': 90.1,
#     'windchill_c': 31.6,
#     'windchill_f': 88.8,
#     'heatindex_c': 32.3,
#     'heatindex_f': 90.1,
#     'dewpoint_c': 16.1,
#     'dewpoint_f': 60.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.1,
#     'gust_kph': 6.6,
#     'uv': 5.9,
#     'short_rad': 780.96,
#     'diff_rad': 101.85,
#     'dni': 4752.66,
#     'gti': 410.43},
#    {'time_epoch': 1758225600,
#     'time': '2025-09-18 16:00',
#     'temp_c': 31.1,
#     'temp_f': 88.0,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 320,
#     'wind_dir': 'NW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 38,
#     'cloud': 49,
#     'feelslike_c': 31.5,
#     'feelslike_f': 88.6,
#     'windchill_c': 31.1,
#     'windchill_f': 88.0,
#     'heatindex_c': 31.5,
#     'heatindex_f': 88.6,
#     'dewpoint_c': 15.5,
#     'dewpoint_f': 59.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.1,
#     'gust_kph': 6.6,
#     'uv': 4.2,
#     'short_rad': 738.74,
#     'diff_rad': 99.18,
#     'dni': 0.0,
#     'gti': 104.4},
#    {'time_epoch': 1758229200,
#     'time': '2025-09-18 17:00',
#     'temp_c': 30.1,
#     'temp_f': 86.3,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 3.6,
#     'wind_kph': 5.8,
#     'wind_degree': 323,
#     'wind_dir': 'NW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.0,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 38,
#     'cloud': 65,
#     'feelslike_c': 30.5,
#     'feelslike_f': 86.8,
#     'windchill_c': 30.1,
#     'windchill_f': 86.3,
#     'heatindex_c': 30.5,
#     'heatindex_f': 86.8,
#     'dewpoint_c': 14.8,
#     'dewpoint_f': 58.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.1,
#     'gust_kph': 6.6,
#     'uv': 2.4,
#     'short_rad': 678.68,
#     'diff_rad': 95.38,
#     'dni': 0.0,
#     'gti': 99.72},
#    {'time_epoch': 1758232800,
#     'time': '2025-09-18 18:00',
#     'temp_c': 29.3,
#     'temp_f': 84.8,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 324,
#     'wind_dir': 'NW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 43,
#     'cloud': 53,
#     'feelslike_c': 29.6,
#     'feelslike_f': 85.3,
#     'windchill_c': 29.3,
#     'windchill_f': 84.8,
#     'heatindex_c': 29.6,
#     'heatindex_f': 85.3,
#     'dewpoint_c': 15.1,
#     'dewpoint_f': 59.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.9,
#     'gust_kph': 6.3,
#     'uv': 1.0,
#     'short_rad': 604.06,
#     'diff_rad': 90.04,
#     'dni': 0.0,
#     'gti': 93.34},
#    {'time_epoch': 1758236400,
#     'time': '2025-09-18 19:00',
#     'temp_c': 28.6,
#     'temp_f': 83.4,
#     'is_day': 1,
#     'condition': {'text': 'Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#      'code': 1006},
#     'wind_mph': 1.8,
#     'wind_kph': 2.9,
#     'wind_degree': 308,
#     'wind_dir': 'NW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 45,
#     'cloud': 47,
#     'feelslike_c': 28.9,
#     'feelslike_f': 84.1,
#     'windchill_c': 28.6,
#     'windchill_f': 83.4,
#     'heatindex_c': 28.9,
#     'heatindex_f': 84.1,
#     'dewpoint_c': 15.3,
#     'dewpoint_f': 59.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.2,
#     'gust_kph': 5.2,
#     'uv': 0.2,
#     'short_rad': 519.92,
#     'diff_rad': 82.18,
#     'dni': 0.0,
#     'gti': 84.52},
#    {'time_epoch': 1758240000,
#     'time': '2025-09-18 20:00',
#     'temp_c': 27.6,
#     'temp_f': 81.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 293,
#     'wind_dir': 'WNW',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.01,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 47,
#     'cloud': 41,
#     'feelslike_c': 28.1,
#     'feelslike_f': 82.7,
#     'windchill_c': 27.6,
#     'windchill_f': 81.6,
#     'heatindex_c': 28.1,
#     'heatindex_f': 82.7,
#     'dewpoint_c': 15.4,
#     'dewpoint_f': 59.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.8,
#     'gust_kph': 4.5,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758243600,
#     'time': '2025-09-18 21:00',
#     'temp_c': 26.8,
#     'temp_f': 80.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 342,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.03,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 53,
#     'cloud': 21,
#     'feelslike_c': 27.5,
#     'feelslike_f': 81.6,
#     'windchill_c': 26.8,
#     'windchill_f': 80.2,
#     'heatindex_c': 27.5,
#     'heatindex_f': 81.6,
#     'dewpoint_c': 16.1,
#     'dewpoint_f': 61.0,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758247200,
#     'time': '2025-09-18 22:00',
#     'temp_c': 25.3,
#     'temp_f': 77.5,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 4.3,
#     'wind_kph': 6.8,
#     'wind_degree': 17,
#     'wind_dir': 'NNE',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 56,
#     'cloud': 10,
#     'feelslike_c': 26.2,
#     'feelslike_f': 79.1,
#     'windchill_c': 25.3,
#     'windchill_f': 77.5,
#     'heatindex_c': 26.2,
#     'heatindex_f': 79.1,
#     'dewpoint_c': 16.4,
#     'dewpoint_f': 61.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 8.9,
#     'gust_kph': 14.4,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758250800,
#     'time': '2025-09-18 23:00',
#     'temp_c': 24.8,
#     'temp_f': 76.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 51,
#     'wind_dir': 'NE',
#     'pressure_mb': 1016.0,
#     'pressure_in': 30.0,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 43,
#     'cloud': 4,
#     'feelslike_c': 26.0,
#     'feelslike_f': 78.8,
#     'windchill_c': 24.8,
#     'windchill_f': 76.7,
#     'heatindex_c': 26.0,
#     'heatindex_f': 78.8,
#     'dewpoint_c': 10.5,
#     'dewpoint_f': 50.9,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.0,
#     'gust_kph': 11.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]},
#  {'date': '2025-09-19',
#   'date_epoch': 1758240000,
#   'day': {'maxtemp_c': 31.1,
#    'maxtemp_f': 88.0,
#    'mintemp_c': 19.4,
#    'mintemp_f': 66.9,
#    'avgtemp_c': 26.2,
#    'avgtemp_f': 79.2,
#    'maxwind_mph': 12.1,
#    'maxwind_kph': 19.4,
#    'totalprecip_mm': 0.0,
#    'totalprecip_in': 0.0,
#    'totalsnow_cm': 0.0,
#    'avgvis_km': 10.0,
#    'avgvis_miles': 6.0,
#    'avghumidity': 59,
#    'daily_will_it_rain': 0,
#    'daily_chance_of_rain': 0,
#    'daily_will_it_snow': 0,
#    'daily_chance_of_snow': 0,
#    'condition': {'text': 'Sunny',
#     'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#     'code': 1000},
#    'uv': 1.5},
#   'astro': {'sunrise': '07:29 AM',
#    'sunset': '07:44 PM',
# ...
#     'wind_kph': 3.2,
#     'wind_degree': 241,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 83,
#     'cloud': 0,
#     'feelslike_c': 19.9,
#     'feelslike_f': 67.9,
#     'windchill_c': 19.9,
#     'windchill_f': 67.9,
#     'heatindex_c': 20.7,
#     'heatindex_f': 69.2,
#     'dewpoint_c': 16.9,
#     'dewpoint_f': 62.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.2,
#     'gust_kph': 6.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758283200,
#     'time': '2025-09-19 08:00',
#     'temp_c': 22.4,
#     'temp_f': 72.4,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.1,
#     'wind_kph': 1.8,
#     'wind_degree': 181,
#     'wind_dir': 'S',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 86,
#     'cloud': 0,
#     'feelslike_c': 23.3,
#     'feelslike_f': 74.0,
#     'windchill_c': 22.4,
#     'windchill_f': 72.4,
#     'heatindex_c': 23.3,
#     'heatindex_f': 74.0,
#     'dewpoint_c': 16.9,
#     'dewpoint_f': 62.5,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.3,
#     'gust_kph': 3.8,
#     'uv': 0.0,
#     'short_rad': 1.47,
#     'diff_rad': 0.7,
#     'dni': 1.05,
#     'gti': 0.91},
#    {'time_epoch': 1758286800,
#     'time': '2025-09-19 09:00',
#     'temp_c': 25.1,
#     'temp_f': 77.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 1.3,
#     'wind_kph': 2.2,
#     'wind_degree': 210,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 68,
#     'cloud': 1,
#     'feelslike_c': 26.3,
#     'feelslike_f': 79.3,
#     'windchill_c': 25.1,
#     'windchill_f': 77.2,
#     'heatindex_c': 26.3,
#     'heatindex_f': 79.3,
#     'dewpoint_c': 18.1,
#     'dewpoint_f': 64.6,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.2,
#     'gust_kph': 3.5,
#     'uv': 0.5,
#     'short_rad': 136.3,
#     'diff_rad': 42.92,
#     'dni': 118.42,
#     'gti': 71.02},
#    {'time_epoch': 1758290400,
#     'time': '2025-09-19 10:00',
#     'temp_c': 27.8,
#     'temp_f': 82.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 197,
#     'wind_dir': 'SSW',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 60,
#     'cloud': 1,
#     'feelslike_c': 29.4,
#     'feelslike_f': 84.9,
#     'windchill_c': 27.8,
#     'windchill_f': 82.0,
#     'heatindex_c': 29.4,
#     'heatindex_f': 84.9,
#     'dewpoint_c': 18.7,
#     'dewpoint_f': 65.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.6,
#     'gust_kph': 4.1,
#     'uv': 1.6,
#     'short_rad': 234.4,
#     'diff_rad': 56.43,
#     'dni': 224.03,
#     'gti': 112.09},
#    {'time_epoch': 1758294000,
#     'time': '2025-09-19 11:00',
#     'temp_c': 29.2,
#     'temp_f': 84.6,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 2.9,
#     'wind_kph': 4.7,
#     'wind_degree': 168,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.1,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 51,
#     'cloud': 1,
#     'feelslike_c': 30.7,
#     'feelslike_f': 87.2,
#     'windchill_c': 29.2,
#     'windchill_f': 84.6,
#     'heatindex_c': 30.7,
#     'heatindex_f': 87.2,
#     'dewpoint_c': 19.3,
#     'dewpoint_f': 66.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.4,
#     'gust_kph': 5.4,
#     'uv': 3.3,
#     'short_rad': 328.7,
#     'diff_rad': 65.94,
#     'dni': 351.74,
#     'gti': 149.9},
#    {'time_epoch': 1758297600,
#     'time': '2025-09-19 12:00',
#     'temp_c': 30.0,
#     'temp_f': 86.0,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 164,
#     'wind_dir': 'SSE',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.09,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 46,
#     'cloud': 29,
#     'feelslike_c': 31.2,
#     'feelslike_f': 88.1,
#     'windchill_c': 30.0,
#     'windchill_f': 86.0,
#     'heatindex_c': 31.2,
#     'heatindex_f': 88.1,
#     'dewpoint_c': 17.6,
#     'dewpoint_f': 63.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.6,
#     'gust_kph': 5.8,
#     'uv': 5.0,
#     'short_rad': 413.14,
#     'diff_rad': 72.92,
#     'dni': 523.75,
#     'gti': 183.72},
#    {'time_epoch': 1758301200,
#     'time': '2025-09-19 13:00',
#     'temp_c': 30.5,
#     'temp_f': 86.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 3.1,
#     'wind_kph': 5.0,
#     'wind_degree': 177,
#     'wind_dir': 'S',
#     'pressure_mb': 1019.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 43,
#     'cloud': 43,
#     'feelslike_c': 31.3,
#     'feelslike_f': 88.3,
#     'windchill_c': 30.5,
#     'windchill_f': 86.8,
#     'heatindex_c': 31.3,
#     'heatindex_f': 88.3,
#     'dewpoint_c': 16.8,
#     'dewpoint_f': 62.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.6,
#     'gust_kph': 5.8,
#     'uv': 6.2,
#     'short_rad': 483.42,
#     'diff_rad': 78.05,
#     'dni': 796.83,
#     'gti': 213.52},
#    {'time_epoch': 1758304800,
#     'time': '2025-09-19 14:00',
#     'temp_c': 30.7,
#     'temp_f': 87.3,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 2.0,
#     'wind_kph': 3.2,
#     'wind_degree': 172,
#     'wind_dir': 'S',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.08,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 41,
#     'cloud': 57,
#     'feelslike_c': 31.4,
#     'feelslike_f': 88.5,
#     'windchill_c': 30.7,
#     'windchill_f': 87.3,
#     'heatindex_c': 31.4,
#     'heatindex_f': 88.5,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.3,
#     'gust_kph': 3.7,
#     'uv': 6.5,
#     'short_rad': 536.51,
#     'diff_rad': 81.74,
#     'dni': 1361.27,
#     'gti': 241.56},
#    {'time_epoch': 1758308400,
#     'time': '2025-09-19 15:00',
#     'temp_c': 30.9,
#     'temp_f': 87.6,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 0.4,
#     'wind_kph': 0.7,
#     'wind_degree': 142,
#     'wind_dir': 'SE',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 40,
#     'cloud': 36,
#     'feelslike_c': 31.5,
#     'feelslike_f': 88.6,
#     'windchill_c': 30.9,
#     'windchill_f': 87.6,
#     'heatindex_c': 31.5,
#     'heatindex_f': 88.6,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 0.5,
#     'gust_kph': 0.8,
#     'uv': 5.6,
#     'short_rad': 777.9,
#     'diff_rad': 99.06,
#     'dni': 4936.5,
#     'gti': 385.35},
#    {'time_epoch': 1758312000,
#     'time': '2025-09-19 16:00',
#     'temp_c': 31.0,
#     'temp_f': 87.8,
#     'is_day': 1,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#      'code': 1003},
#     'wind_mph': 1.8,
#     'wind_kph': 2.9,
#     'wind_degree': 329,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 40,
#     'cloud': 26,
#     'feelslike_c': 31.5,
#     'feelslike_f': 88.8,
#     'windchill_c': 31.0,
#     'windchill_f': 87.8,
#     'heatindex_c': 31.5,
#     'heatindex_f': 88.8,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 2.1,
#     'gust_kph': 3.3,
#     'uv': 4.0,
#     'short_rad': 697.22,
#     'diff_rad': 164.13,
#     'dni': 0.0,
#     'gti': 161.48},
#    {'time_epoch': 1758315600,
#     'time': '2025-09-19 17:00',
#     'temp_c': 30.2,
#     'temp_f': 86.3,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.4,
#     'wind_kph': 5.4,
#     'wind_degree': 337,
#     'wind_dir': 'NNW',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.05,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 40,
#     'cloud': 16,
#     'feelslike_c': 30.7,
#     'feelslike_f': 87.3,
#     'windchill_c': 30.2,
#     'windchill_f': 86.3,
#     'heatindex_c': 30.7,
#     'heatindex_f': 87.3,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 3.9,
#     'gust_kph': 6.2,
#     'uv': 2.2,
#     'short_rad': 622.72,
#     'diff_rad': 176.17,
#     'dni': 0.0,
#     'gti': 170.63},
#    {'time_epoch': 1758319200,
#     'time': '2025-09-19 18:00',
#     'temp_c': 29.3,
#     'temp_f': 84.8,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 4.7,
#     'wind_kph': 7.6,
#     'wind_degree': 356,
#     'wind_dir': 'N',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 45,
#     'cloud': 14,
#     'feelslike_c': 29.9,
#     'feelslike_f': 85.8,
#     'windchill_c': 29.3,
#     'windchill_f': 84.8,
#     'heatindex_c': 29.9,
#     'heatindex_f': 85.8,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 6.3,
#     'gust_kph': 10.1,
#     'uv': 0.9,
#     'short_rad': 540.22,
#     'diff_rad': 166.62,
#     'dni': 0.0,
#     'gti': 160.34},
#    {'time_epoch': 1758322800,
#     'time': '2025-09-19 19:00',
#     'temp_c': 28.5,
#     'temp_f': 83.2,
#     'is_day': 1,
#     'condition': {'text': 'Sunny',
#      'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#      'code': 1000},
#     'wind_mph': 3.8,
#     'wind_kph': 6.1,
#     'wind_degree': 353,
#     'wind_dir': 'N',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 47,
#     'cloud': 13,
#     'feelslike_c': 29.0,
#     'feelslike_f': 84.2,
#     'windchill_c': 28.5,
#     'windchill_f': 83.2,
#     'heatindex_c': 29.0,
#     'heatindex_f': 84.2,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 7.2,
#     'gust_kph': 11.6,
#     'uv': 0.2,
#     'short_rad': 460.85,
#     'diff_rad': 146.95,
#     'dni': 0.0,
#     'gti': 141.07},
#    {'time_epoch': 1758326400,
#     'time': '2025-09-19 20:00',
#     'temp_c': 27.6,
#     'temp_f': 81.7,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 2.2,
#     'wind_kph': 3.6,
#     'wind_degree': 1,
#     'wind_dir': 'N',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 49,
#     'cloud': 12,
#     'feelslike_c': 28.3,
#     'feelslike_f': 83.0,
#     'windchill_c': 27.6,
#     'windchill_f': 81.7,
#     'heatindex_c': 28.3,
#     'heatindex_f': 83.0,
#     'dewpoint_c': 16.0,
#     'dewpoint_f': 60.7,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 4.7,
#     'gust_kph': 7.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758330000,
#     'time': '2025-09-19 21:00',
#     'temp_c': 27.0,
#     'temp_f': 80.6,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 12.1,
#     'wind_kph': 19.4,
#     'wind_degree': 239,
#     'wind_dir': 'WSW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.06,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 54,
#     'cloud': 33,
#     'feelslike_c': 27.9,
#     'feelslike_f': 82.2,
#     'windchill_c': 27.0,
#     'windchill_f': 80.6,
#     'heatindex_c': 27.9,
#     'heatindex_f': 82.2,
#     'dewpoint_c': 16.7,
#     'dewpoint_f': 62.1,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 18.8,
#     'gust_kph': 30.3,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758333600,
#     'time': '2025-09-19 22:00',
#     'temp_c': 26.2,
#     'temp_f': 79.2,
#     'is_day': 0,
#     'condition': {'text': 'Partly Cloudy ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/116.png',
#      'code': 1003},
#     'wind_mph': 10.1,
#     'wind_kph': 16.2,
#     'wind_degree': 314,
#     'wind_dir': 'NW',
#     'pressure_mb': 1018.0,
#     'pressure_in': 30.07,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 57,
#     'cloud': 43,
#     'feelslike_c': 27.2,
#     'feelslike_f': 81.0,
#     'windchill_c': 26.2,
#     'windchill_f': 79.2,
#     'heatindex_c': 27.2,
#     'heatindex_f': 81.0,
#     'dewpoint_c': 17.1,
#     'dewpoint_f': 62.8,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 15.4,
#     'gust_kph': 24.8,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0},
#    {'time_epoch': 1758337200,
#     'time': '2025-09-19 23:00',
#     'temp_c': 25.5,
#     'temp_f': 77.9,
#     'is_day': 0,
#     'condition': {'text': 'Clear ',
#      'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#      'code': 1000},
#     'wind_mph': 6.5,
#     'wind_kph': 10.4,
#     'wind_degree': 350,
#     'wind_dir': 'N',
#     'pressure_mb': 1017.0,
#     'pressure_in': 30.04,
#     'precip_mm': 0.0,
#     'precip_in': 0.0,
#     'snow_cm': 0.0,
#     'humidity': 59,
#     'cloud': 0,
#     'feelslike_c': 26.7,
#     'feelslike_f': 80.1,
#     'windchill_c': 25.5,
#     'windchill_f': 77.9,
#     'heatindex_c': 26.7,
#     'heatindex_f': 80.1,
#     'dewpoint_c': 16.8,
#     'dewpoint_f': 62.2,
#     'will_it_rain': 0,
#     'chance_of_rain': 0,
#     'will_it_snow': 0,
#     'chance_of_snow': 0,
#     'vis_km': 10.0,
#     'vis_miles': 6.0,
#     'gust_mph': 11.0,
#     'gust_kph': 17.6,
#     'uv': 0,
#     'short_rad': 0,
#     'diff_rad': 0,
#     'dni': 0,
#     'gti': 0}]}]

# %%
forecast_3_days_summary = []
for day in forecast:
    forecast_3_days_summary.append(f"{day['date']}: High {day['day']['maxtemp_f']}F, Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

# %%
forecast_3_days_summary
# Out:
# ['2025-09-17: High 93.2F, Low 67.1F - Sunny',
#  '2025-09-18: High 91.8F, Low 66.7F - Sunny',
#  '2025-09-19: High 88.0F, Low 66.9F - Sunny']

# %%
forecast_3_days_summary = []
for day in forecast:
    date_obj = datetime.strptime(day['date'], '%Y-%m-%d')
    formatted_date = date_obj.strftime('%A, %B %#d')
    forecast_3_days_summary.append(f"{formatted_date}: High {day['day']['maxtemp_f']}F, Low {day['day']['mintemp_f']}F - {day['day']['condition']['text']}")

forecast_3_days_summary
# Out:
# ['Wednesday, September 17: High 93.2F, Low 67.1F - Sunny',
#  'Thursday, September 18: High 91.8F, Low 66.7F - Sunny',
#  'Friday, September 19: High 88.0F, Low 66.9F - Sunny']

# %%
today = pd.Timestamp.now().strftime("%Y-%m-%d")
astronomy_url = f"{baseurl}astronomy.json?key={api_key}&q={city}&dt={today}"

# %%
def get_city_data(city, api_key):
    # get current weather
    # get a forecast
    # get some astronomical data
    # get anything else you want (challenge)

    # build a summary for the city, save that summary into a dictionary

# %%
# build a dataframe form various cities, save to csv file
